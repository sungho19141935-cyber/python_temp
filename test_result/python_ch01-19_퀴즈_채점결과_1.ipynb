# %% [markdown]
# # Python 기초 Chapter 01~19 복습 퀴즈 채점 결과
#
# A형(1~38번) · B형(39~76번), 76문항 채점 결과입니다.
#
# **총점: 43 / 76점 (56.6%) — A형 19/38점, B형 24/38점
#
# **채점 기준**
# - 단답형 1점 — 표현이 달라도 핵심 개념이 같으면 정답으로 인정 (아래 표에서 `O*`로 표시)
# - 다중선택형 1점 — 정답 보기 전체 일치 시에만 정답, 일부만 맞으면 오답

# %%
import pandas as pd

columns = ["번호", "유형", "학생 답안", "정답", "정답여부", "메모"]

A = [(1, '단답', '컴퓨터 언어 이해', '컴퓨터가 해야 할 일과 순서를 명확하게 설명하는 과정', False, "핵심 표현과 다릅니다. '무엇을 어떤 순서로 할지 명확히 설명하는 것'이 정답입니다."), (2, '다중선택', '①②④', '①②④', True, ''), (3, '단답', '인터프리터', 'Python 실행기(인터프리터)', True, ''), (4, '다중선택', '①②', '①②④', False, '④(설치 후 새 터미널에서 재확인)도 포함되어야 합니다.'), (5, '단답', '?', '오류 메시지(실제 실행 결과)', False, '답안이 입력되지 않았습니다.'), (6, '다중선택', '①④', '①②③④', False, '②③(수준, 목표)도 포함되어야 합니다.'), (7, '단답', '밸류에러', 'Python 100', False, 'print("Python", 100)의 출력 결과를 그대로 쓰는 문제입니다.'), (8, '다중선택', '①②③⑤', '①②③⑤', True, ''), (9, '단답', 'str', 'str', True, ''), (10, '다중선택', '①②', '①②③⑤', False, '③⑤도 맞는 설명입니다.'), (11, '단답', '3, 2', '3, 2', True, ''), (12, '다중선택', '①②', '①②③⑤', False, '③⑤도 포함되어야 합니다.'), (13, '단답', 'yth', 'yth', True, ''), (14, '다중선택', '①②③⑤', '①②③⑤', True, ''), (15, '단답', '문자형', 'str', True, '인정(표현 차이): 문자형 = str, 같은 의미.'), (16, '다중선택', '①②③', '①②③⑤', False, '⑤도 포함되어야 합니다.'), (17, '단답', '통과', '통과', True, ''), (18, '다중선택', '②④⑤', '①②④⑤', False, '①도 포함되어야 합니다.'), (19, '단답', '5', '5번', True, ''), (20, '다중선택', '①②③', '①②③⑤', False, '⑤도 포함되어야 합니다.'), (21, '단답', 'fruits[-1]', 'fruits[-1] (또는 fruits[2])', True, ''), (22, '다중선택', '①②④⑤', '①②④⑤', True, ''), (23, '단답', ',', '쉼표(,)', True, ''), (24, '다중선택', '①②⑤', '①②③⑤', False, '③도 포함되어야 합니다.'), (25, '단답', 'student["score"]', 'student["score"]', True, ''), (26, '다중선택', '①②', '①②③⑤', False, '③⑤도 포함되어야 합니다.'), (27, '단답', 'return', 'return', True, ''), (28, '다중선택', '①③⑤', '①③⑤', True, ''), (29, '단답', 'python -m venv .venv', 'venv(가상환경)', True, '인정(표현 차이): venv 실행 명령까지 정확히 작성해 개념을 정확히 알고 있음.'), (30, '다중선택', '①②④⑤', '①②③⑤', False, '④는 틀린 설명(가상환경마다 패키지 버전이 다를 수 있음)이며 ③이 포함되어야 합니다.'), (31, '단답', 'ps', 'r', False, ''), (32, '다중선택', '①③', '①②③⑤', False, '②⑤도 포함되어야 합니다.'), (33, '단답', 'TypeError', 'ValueError', False, ''), (34, '다중선택', '①③⑤', '①③④⑤', False, '④(finally)도 포함되어야 합니다.'), (35, '단답', '붕어빵 틀', '객체(object)', False, "'틀'은 클래스에 해당합니다. 틀로 만들어진 실제 결과물(붕어빵)이 객체입니다."), (36, '다중선택', '①③④', '①③④', True, ''), (37, '단답', 'ipo', 'IPO', True, ''), (38, '다중선택', '①③⑤', '①②③⑤', False, '②도 포함되어야 합니다.')]

B = [(39, '단답', '구현 검증 수정 확인', '읽고, 실행하고, 수정하고, 검증하는 능력', False, '정확한 네 동사(읽고·실행하고·수정하고·검증하는)와 다릅니다.'), (40, '다중선택', '①②④', '①②④', True, ''), (41, '단답', 'python --v', 'python --version (Windows: py --version)', False, "'--v'가 아니라 '--version'입니다."), (42, '다중선택', '①③④', '①②③④', False, '②도 포함되어야 합니다.'), (43, '단답', '개인정보 회사기밀', '비밀번호 / API 키 / 개인정보 중 하나', True, ''), (44, '다중선택', '①②③⑤', '①②③⑤', True, ''), (45, '단답', '#', '#', True, ''), (46, '다중선택', '①②⑤', '①②⑤', True, ''), (47, '단답', 'value error', 'ValueError', True, '인정(표현 차이): 대소문자·띄어쓰기만 다름.'), (48, '다중선택', '③④', '①②③④', False, '①②도 포함되어야 합니다.'), (49, '단답', '9', '9', True, ''), (50, '다중선택', '①③④', '①③④', True, ''), (51, '단답', 'n', 'n', True, ''), (52, '다중선택', '①②③④', '①②③④', True, ''), (53, '단답', '13', '13', True, ''), (54, '다중선택', '①②③④', '①②③⑤', False, '④가 아니라 ⑤(들여쓰기 확인)가 포함되어야 합니다.'), (55, '단답', 'B', 'B', True, ''), (56, '다중선택', '②③④⑤', '①②④⑤', False, '①이 포함되고 ③은 제외되어야 합니다 (=는 대입, ==가 비교연산자).'), (57, '단답', '10', '6', False, 'total: 1+2+3 = 6 입니다.'), (58, '다중선택', '①②④', '①②④⑤', False, '⑤도 포함되어야 합니다.'), (59, '단답', '[1, 2, 3]', '[1, 2, 3]', True, ''), (60, '다중선택', '①②④', '①②③④', False, '③도 포함되어야 합니다.'), (61, '단답', 'set()', 'set()', True, ''), (62, '다중선택', '①②③⑤', '①②③⑤', True, ''), (63, '단답', 'get(), in', 'get()', True, '인정(표현 차이): get()이 핵심 정답이며 in은 참고로 덧붙인 내용.'), (64, '다중선택', '①②③④', '①②③④', True, ''), (65, '단답', '매개변수', '매개변수(parameter)', True, ''), (66, '다중선택', '①②③④', '①②③④', True, ''), (67, '단답', 'requirements.txt', 'requirements.txt', True, ''), (68, '다중선택', '①③⑤', '①②③⑤', False, '②도 포함되어야 합니다.'), (69, '단답', 'a', 'a', True, ''), (70, '다중선택', '②③⑤', '①②③⑤', False, '①도 포함되어야 합니다.'), (71, '단답', '예외 이름, 오류 메시지', '예외 이름과 설명', True, '인정(표현 차이): 오류 메시지 ≈ 설명, 같은 취지.'), (72, '다중선택', '①②③④', '①②③⑤', False, '④가 아니라 ⑤(KeyError)가 포함되어야 합니다.'), (73, '단답', '__init__', '__init__()', True, '인정(표현 차이): 괄호 생략, 동일 메서드명.'), (74, '다중선택', '①②', '①②④⑤', False, '④⑤도 포함되어야 합니다.'), (75, '단답', 'def', '함수', True, "인정(표현 차이): def는 함수를 정의하는 키워드로, '함수' 개념을 알고 있음을 보여줌."), (76, '다중선택', '①②③', '①②③④', False, '④도 포함되어야 합니다.')]

def to_df(rows):
    df = pd.DataFrame(rows, columns=columns)
    df["Ch"] = df["번호"].apply(lambda n: f"{((n-1 if n<=38 else n-39)//2)+1:02d}")
    df["채점"] = df.apply(lambda r: ("O*" if (r["정답여부"] and str(r["메모"]).startswith("인정")) else ("O" if r["정답여부"] else "X")), axis=1)
    return df[["번호","Ch","유형","학생 답안","정답","채점","메모"]]

df_A = to_df(A)
df_B = to_df(B)
df_all = pd.concat([df_A, df_B], ignore_index=True)

total = len(df_all)
correct = int(df_all["채점"].isin(["O","O*"]).sum())
a_correct = int(df_A["채점"].isin(["O","O*"]).sum())
b_correct = int(df_B["채점"].isin(["O","O*"]).sum())

print(f"총점: {correct} / {total}점")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2
#       3 columns = ["번호", "유형", "학생 답안", "정답", "정답여부", "메모"]
#       4
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## A형 (1~38번)

# %%
def highlight(row):
    color = {"O": "#e2efda", "O*": "#fff2cc", "X": "#fce4e4"}.get(row["채점"], "")
    return [f"background-color: {color}"] * len(row)

df_A.style.apply(highlight, axis=1)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## B형 (39~76번)

# %%
df_B.style.apply(highlight, axis=1)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## 오답 요약
#
# 자주 나온 오답 패턴:
# - 다중선택에서 정답 보기 일부를 빠뜨린 경우 (4, 6, 10, 12, 16, 18, 20, 24, 26, 30, 32, 34, 38, 42, 48, 54, 56, 58, 60, 68, 70, 72, 74, 76번)
# - 단답형에서 다른 개념/예외로 착각한 경우 (7, 33, 35, 41, 57번)
